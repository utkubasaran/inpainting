# %% [markdown]
# # Clothing Recolor for Colab
#
# Run the cells below to clone the repo, install dependencies, start AUTOMATIC1111 with API enabled, and launch the Gradio app.

# %%
# !git clone YOUR_GITHUB_REPO_URL project
# %cd project

# %%
# !pip install -q -r requirements.txt

# %%
# %cd /content
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui.git a1111
# %cd /content/a1111
# !COMMANDLINE_ARGS="--api --listen --port 7861 --xformers" REQS_FILE="requirements_versions.txt" python launch.py > /content/a1111.log 2>&1 &

# %%
# !python - <<'PY'
import time, requests
for _ in range(120):
    try:
        r = requests.get('http://127.0.0.1:7861/sdapi/v1/sd-models', timeout=5)
        if r.ok:
            print('A1111 API ready')
            break
    except Exception:
        pass
    time.sleep(5)
else:
    raise SystemExit('A1111 API did not become ready in time. Check /content/a1111.log')
PY

# %%
# %cd /content/project
# !A1111_BASE_URL=http://127.0.0.1:7861 python app.py
