# %% [markdown]
# # Clothing Recolor for Colab
#
# Run the cells below to clone the repo, install dependencies, and launch the Gradio app.

# %%
# !git clone YOUR_GITHUB_REPO_URL project
# %cd project

# %%
# !pip install -q -r requirements.txt

# %%
# !python app.py
